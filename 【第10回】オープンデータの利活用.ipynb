# %% [markdown]
# <a href="https://colab.research.google.com/github/DSF-Kotaro/classroom/blob/main/%E3%80%90%E7%AC%AC10%E5%9B%9E%E3%80%91%E3%82%AA%E3%83%BC%E3%83%97%E3%83%B3%E3%83%87%E3%83%BC%E3%82%BF%E3%81%AE%E5%88%A9%E6%B4%BB%E7%94%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #オープンデータの読み込み（load open data）

# %% [markdown]
# ##student-mat.csv,student-por.csvの読み込み（Load files 'student-mat.csv'and 'student-por.csv'）

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

student_data_math = pd.read_csv('student-mat.csv',sep=';')

# %%
student_data_math
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0       GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1       GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2       GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3       GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4       GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# ..     ...  ..  ...     ...     ...     ...  ...   ...     ...      ...  ..  ..  ..
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# ...

# %% [markdown]
# #箱ひげ図（Box plot）

# %%
plt.boxplot(student_data_math['G1'])
plt.grid(True)

# %%
plt.boxplot(student_data_math['absences'])
plt.grid(True)

# %%
plt.boxplot([student_data_math["G1"],student_data_math["G2"],student_data_math["G3"]])
plt.grid(True)

# %% [markdown]
# #散布図と相関係数（Scatter plot and correlation coefficient）

# %%
#Scatter plot
plt.plot(student_data_math["G1"],student_data_math["G3"],'o')

#Label
plt.ylabel("G3 grade")
plt.xlabel("G1 grade")
plt.grid(True)

# %% [markdown]
# #全ての変数のヒストグラムや散布図を描く（Draw histograms and scatter plots of all variables）

# %%
sns.pairplot(student_data_math[['Dalc','Walc','G1','G3']])
plt.grid(True)

# %% [markdown]
# #問題（Question）

# %% [markdown]
# ##問題１（Question１）
# 「student-port.csv」を読み込んで、要約統計量を表示してください。
# <br>（Please read "student-port.csv" to view the summary statistics.）

# %% [markdown]
# #問題２（Question 2）
# 以下のプログラムを実行してください。

# %%
student_data_math = pd.read_csv("student-mat.csv",sep=";")
student_data_por = pd.read_csv("student-mat.csv",sep=";")

student_data_merge = pd.merge(student_data_math,
                              student_data_por,
                              on = ['school','sex','age','address','famsize','Pstatus','Medu',
                                    'Fedu','Mjob','Fjob','reason','nursery','internet'],
                              suffixes = ('_math','_por'))
student_data_merge.describe()
# Out:
#               age        Medu        Fedu  ...      G1_por      G2_por      G3_por
# count  403.000000  403.000000  403.000000  ...  403.000000  403.000000  403.000000
# mean    16.697270    2.759305    2.531017  ...   10.895782   10.697270   10.369727
# std      1.268708    1.092321    1.093129  ...    3.326220    3.798097    4.648841
# min     15.000000    0.000000    0.000000  ...    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000  ...    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    3.000000  ...   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000  ...   13.000000   13.000000   14.000000
# max     22.000000    4.000000    4.000000  ...   19.000000   19.000000   20.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# #問題３（Question３）
# 問題２でマージしたデータについて、「Medu」「Fedu」「G3_math」などの変数をいくつかピックアップして、散布図とヒストグラムを作成してみましょう。
# <br>（Let's pick up some variables such as "Medu", "Fedu", and "G3_math" for the data merged in Problem 2 and create a scatter plot and a histogram.）
